# %% [markdown]
# # 3. Model selection for recommender systems

# %%
import pandas as pd
import numpy as np

#import reader, crossvalidation, models ametrics from surprise
from surprise import Reader, Dataset
from surprise.model_selection import LeaveOneOut, cross_validate
from surprise import KNNBaseline, KNNBasic, SVD, NMF, accuracy

# %%
# Load data
df = pd.read_csv('../data/reviews_filtered.csv')
df.head()
# Out:
#                      name  review_stars  \
# 0  Deagan's Kitchen & Bar             5
# 1  Deagan's Kitchen & Bar             4
# 2  Deagan's Kitchen & Bar             4
# 3  Deagan's Kitchen & Bar             3
# 4  Deagan's Kitchen & Bar             2
#
#                                         cleaned_text  sent_rating  uid
# 0  we walked into melt did you want to put your n...     3.505159    0
# 1  brunch on saturday was excellent the bloody ma...     3.800000    1
# 2  great food great atmosphere great service some...     3.587500    2
# 3  had a saturday evening dinner with friends goi...     3.436378    3
# 4  i haven't been here for years i'm not from thi...     2.981408    4

# %%
# Rating df
df_ratings = df[['uid', 'name', 'review_stars']]
df_ratings.columns = ['uid', 'restaurant', 'rating']
df_ratings.head()
# Out:
#    uid              restaurant  rating
# 0    0  Deagan's Kitchen & Bar       5
# 1    1  Deagan's Kitchen & Bar       4
# 2    2  Deagan's Kitchen & Bar       4
# 3    3  Deagan's Kitchen & Bar       3
# 4    4  Deagan's Kitchen & Bar       2

# %%
# Sentiment df
df_sentiment = df[['uid', 'name', 'sent_rating']]
df_sentiment.columns = ['uid', 'restaurant', 'rating']
df_sentiment.head()
# Out:
#    uid              restaurant    rating
# 0    0  Deagan's Kitchen & Bar  3.505159
# 1    1  Deagan's Kitchen & Bar  3.800000
# 2    2  Deagan's Kitchen & Bar  3.587500
# 3    3  Deagan's Kitchen & Bar  3.436378
# 4    4  Deagan's Kitchen & Bar  2.981408

# %%
# Models to test
algorithms_cv = {'svd': SVD(),
              'NMF': NMF(), 
              'kNN_pearson': KNNBasic(sim_options={'name': 'pearson', 'user_based': False }), 
              'kNN_cosine': KNNBasic(sim_options= {'name': 'cosine', 'user_based': False}), 
              'kNN_msd': KNNBasic(sim_options={'name': 'msd', 'user_based': False}), 
              }

# %%
def model_validation(df, algorithms):
    
    data = Dataset.load_from_df(df, Reader(rating_scale=(1,5)))

    benchmark = []
    # Iterate over all algorithms
    for model, algorithm in algorithms.items():
        # Perform cross validation
        results = cross_validate(algorithm, data, measures=['RMSE', 'MSE', 'MAE'], cv=10, 
                                 verbose=False)     
        
        # Get results & append algorithm name
        tmp = pd.DataFrame.from_dict(results).mean(axis=0)
        tmp = tmp.append(pd.Series(model, index=['Algorithm']))
        benchmark.append(tmp)
    
    output = pd.DataFrame(benchmark).set_index('Algorithm').sort_values('test_rmse')
    output.columns = ['RMSE(K=10)','MSE(K=10)', 'MAE(K=10)', 'fit_time', 'test_time']
    return output

# %%
# Ratings
results_ratings = model_validation(df_ratings, algorithms_cv)
results_ratings
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
#              RMSE(K=10)  MSE(K=10)  MAE(K=10)   fit_time  test_time
# Algorithm
# svd            0.973449   0.947614   0.758114  18.564372   0.417548
# kNN_msd        1.006659   1.013394   0.778598  11.720646   5.826927
# NMF            1.015683   1.031625   0.791281  23.013564   0.303335
# kNN_cosine     1.019681   1.039753   0.795297  21.941919   5.711867
# kNN_pearson    1.048384   1.099115   0.813277  28.062884   5.360159

# %%
results_ratings.to_csv('../data/model_ratings.csv')

# %%
# Sentiment analysis
results_sentiment = model_validation(df_sentiment, algorithms_cv)
results_sentiment
# Out:
# Computing the pearson similarity matrix...
# /opt/conda/lib/python3.7/site-packages/surprise/prediction_algorithms/algo_base.py:248: RuntimeWarning: invalid value encountered in sqrt
#   sim = construction_func[name](*args)
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
#              RMSE(K=10)  MSE(K=10)  MAE(K=10)   fit_time  test_time
# Algorithm
# svd            0.314934   0.099187   0.234481  18.636536   0.380283
# kNN_msd        0.315911   0.099801   0.233730  21.014045  10.276739
# kNN_cosine     0.317016   0.100501   0.234848  38.271068  10.105334
# kNN_pearson    0.326278   0.106462   0.241660  37.860483   7.578257
# NMF            0.328185   0.107709   0.245183  24.637818   0.383059

# %%
results_sentiment.to_csv('../data/model_sentiment.csv')

# %%
# Rounded sentiment
df_sentiment_rounded = df_sentiment.copy()
df_sentiment_rounded['rounded'] = df_sentiment_rounded['rating'].apply(round)
df_sentiment_rounded.drop('rating', axis=1, inplace=True)
df_sentiment_rounded.columns = ['uid', 'restaurant', 'rating']

# %%
results_sentiment_rounded = model_validation(df_sentiment_rounded, algorithms_cv)
results_sentiment_rounded

# %%
results_sentiment_rounded.to_csv('model_sentiment_rounded.csv')

# %%
algorithms_tunning = {'SVD': SVD,
              #'kNN': KNNBasic
              }

# %%
#Hyperparameter tunning

from surprise.model_selection import GridSearchCV
def parameter_selection(df, algorithms):
    data = Dataset.load_from_df(df, Reader(rating_scale=(1,5)))
    
    for model, algorithm in algorithms.items():
        if model == 'SVD':
            param_grid = {'n_factors':[50,100,200,500],
                      'n_epochs':[20,30,50], 'lr_all':[0.002,0.005,0.01],
                      'reg_all':[0.02,0.06,0.08]}
        
        elif model == 'kNN':
            param_grid = {'k': [20, 30, 40, 50], #number of neighbors for computation
              'sim_options': {'name': ['msd', 'cosine'],
                              'min_support': [5, 10], #minimum number of common users
                              'user_based': [False]}
              }
        else: raise ValueError('The model provided is not valid')

    gs = GridSearchCV(algorithm, param_grid, measures=['rmse'], cv=2)
    gs.fit(data)
    params = gs.best_params['rmse']
    print(f'The best combination of parameters is {params}')
    return pd.DataFrame.from_dict(gs.cv_results)

# %%
parameter_tunning_SVD = parameter_selection(df_ratings, algorithms_tunning)
# Out:
# The best combination of parameters is {'n_factors': 50, 'n_epochs': 50, 'lr_all': 0.002, 'reg_all': 0.08}

# %%
parameter_tunning_kNN = parameter_selection(df_sentiment, algorithms_tunning)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# The best combination of parameters is {'k': 50, 'sim_options': {'name': 'msd', 'min_support': 5, 'user_based': False}}

# %%
parameter_tunning_kNN
# Out:
#     split0_test_rmse  split1_test_rmse  split2_test_rmse  split3_test_rmse  \
# 0           0.331176          0.326122          0.327200          0.325552
# 1           0.337828          0.331836          0.334213          0.331012
# 2           0.332308          0.327461          0.328498          0.326620
# 3           0.338881          0.332774          0.335301          0.331862
# 4           0.330047          0.324929          0.326025          0.324253
# 5           0.337288          0.331343          0.333745          0.330326
# 6           0.331096          0.325949          0.327115          0.325077
# 7           0.338131          0.332051          0.334379          0.331112
# 8           0.329721          0.324714          0.325875          0.323905
# 9           0.337264          0.331393          0.333733          0.330261
# 10          0.330520          0.325524          0.326744          0.324593
# 11          0.337955          0.331902          0.334246          0.330836
# 12          0.329646          0.324657          0.325873          0.323829
# 13          0.337227          0.331352          0.333787          0.330202
# 14          0.330381          0.325334          0.326638          0.324410
# 15          0.337801          0.331863          0.334239          0.330717
#
#     split4_test_rmse  mean_test_rmse  std_test_rmse  rank_test_rmse  \
# 0           0.326830        0.327376       0.001983               7
# 1           0.334610        0.333900       0.002393              13
# 2           0.328066        0.328591       0.001963               8
# 3           0.335539        0.334871       0.002456              16
# 4           0.325598        0.326170       0.002030               3
# 5           0.334209        0.333382       0.002432              11
# 6           0.326623        0.327172       0.002078               6
# 7           0.334822        0.334099       0.002448              15
# 8           0.325425        0.325928       0.002010               2
# 9           0.334090        0.333348       0.002424              10
# 10          0.326275        0.326731       0.002029               5
# 11          0.334673        0.333922       0.002471              14
# 12          0.325406        0.325882       0.002006               1
# 13          0.334109        0.333335       0.002437               9
# 14          0.326063        0.326565       0.002048               4
# 15          0.334644        0.333853       0.002456              12
#
#     mean_fit_time  std_fit_time  mean_test_time  std_test_time  \
# 0        9.316437      0.483462        6.963662       0.114057
# 1        9.093746      0.103283        6.568290       0.018130
# 2       13.982414      0.407793        6.888127       0.044124
# 3       13.369857      0.140478        6.521981       0.040281
# 4        9.056341      0.174814        7.453658       0.008212
# 5        9.019775      0.122308        7.091444       0.011718
# 6       13.752759      0.156870        7.496678       0.025835
# 7       13.215264      0.153282        7.065522       0.058042
# 8        9.047763      0.128921        7.899655       0.011416
# 9        9.042331      0.152299        7.470124       0.025896
# 10      14.021343      0.523687        8.110764       0.276480
# 11      13.314166      0.283521        7.457223       0.113079
# 12       9.006409      0.101472        7.991244       0.024880
# 13       8.974023      0.121285        7.561583       0.044799
# 14      13.674910      0.156668        8.027755       0.029995
# 15      13.175648      0.132996        7.549497       0.066103
#
#                                                params  param_k  \
# 0   {'k': 20, 'sim_options': {'name': 'msd', 'min_...       20
# 1   {'k': 20, 'sim_options': {'name': 'msd', 'min_...       20
# 2   {'k': 20, 'sim_options': {'name': 'cosine', 'm...       20
# 3   {'k': 20, 'sim_options': {'name': 'cosine', 'm...       20
# 4   {'k': 30, 'sim_options': {'name': 'msd', 'min_...       30
# 5   {'k': 30, 'sim_options': {'name': 'msd', 'min_...       30
# 6   {'k': 30, 'sim_options': {'name': 'cosine', 'm...       30
# 7   {'k': 30, 'sim_options': {'name': 'cosine', 'm...       30
# 8   {'k': 40, 'sim_options': {'name': 'msd', 'min_...       40
# 9   {'k': 40, 'sim_options': {'name': 'msd', 'min_...       40
# 10  {'k': 40, 'sim_options': {'name': 'cosine', 'm...       40
# 11  {'k': 40, 'sim_options': {'name': 'cosine', 'm...       40
# 12  {'k': 50, 'sim_options': {'name': 'msd', 'min_...       50
# 13  {'k': 50, 'sim_options': {'name': 'msd', 'min_...       50
# 14  {'k': 50, 'sim_options': {'name': 'cosine', 'm...       50
# 15  {'k': 50, 'sim_options': {'name': 'cosine', 'm...       50
#
#                                     param_sim_options
# 0   {'name': 'msd', 'min_support': 5, 'user_based'...
# 1   {'name': 'msd', 'min_support': 10, 'user_based...
# 2   {'name': 'cosine', 'min_support': 5, 'user_bas...
# 3   {'name': 'cosine', 'min_support': 10, 'user_ba...
# 4   {'name': 'msd', 'min_support': 5, 'user_based'...
# 5   {'name': 'msd', 'min_support': 10, 'user_based...
# 6   {'name': 'cosine', 'min_support': 5, 'user_bas...
# 7   {'name': 'cosine', 'min_support': 10, 'user_ba...
# 8   {'name': 'msd', 'min_support': 5, 'user_based'...
# 9   {'name': 'msd', 'min_support': 10, 'user_based...
# 10  {'name': 'cosine', 'min_support': 5, 'user_bas...
# 11  {'name': 'cosine', 'min_support': 10, 'user_ba...
# 12  {'name': 'msd', 'min_support': 5, 'user_based'...
# 13  {'name': 'msd', 'min_support': 10, 'user_based...
# 14  {'name': 'cosine', 'min_support': 5, 'user_bas...
# 15  {'name': 'cosine', 'min_support': 10, 'user_ba...

# %%
parameter_tunning_SVD.to_csv('../data/tunning_SVD.csv')
